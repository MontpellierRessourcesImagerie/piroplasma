# %%
import os.path

project_file = "bbs.yaml"
assert os.path.exists(project_file)

# %%
from ultralytics import YOLO
# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# %%
# Monkey patch method to use weighted dataloader
# This might not work with multi-GPU training.
# Go to the end of the notebook for multi-GPU workaround.
import ultralytics.data.build as build
from piroplasma.data.loader import YOLOWeightedDataset

build.YOLODataset = YOLOWeightedDataset

# %%
results = model.train(cfg="augmented_train.yaml")
# Out:
# New https://pypi.org/project/ultralytics/8.4.155 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.75 🚀 Python-3.10.19 torch-2.12.1+cu130 CUDA:0 (Quadro RTX 5000, 15920MiB)
# ...
