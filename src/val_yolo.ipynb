# %%
import os.path

project_file = "bbs.yaml"
assert os.path.exists(project_file)

# %%
from ultralytics import YOLO
# Load a custom trained YOLO26n model
model = YOLO('runs/detect/train-18/weights/best.pt')

# %%
metrics = model.val()
# Out:
# Ultralytics 8.4.75 🚀 Python-3.10.19 torch-2.12.1+cu130 CUDA:0 (Quadro RTX 5000, 15920MiB)
# YOLO26n summary (fused): 122 layers, 2,375,811 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 99.5±16.0 MB/s, size: 7500.3 KB)
# val: Scanning /run/media/baecker/data/programs/Fiji/mri-tools/piroplasma/src/datasets/ds260901/val.cache... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 735.8Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6s/it 2.6s
#                    all         10        304      0.609      0.607      0.637      0.527
#                    GR+          9         23      0.664      0.783      0.712      0.657
#                    GR-         10        110      0.816      0.926      0.946      0.807
#                     GB          6         18      0.734      0.444      0.645      0.488
#                 Border         10        145       0.83      0.883       0.86      0.672
#                    Bin          5          8          0          0     0.0213     0.0133
# Speed: 3.5ms preprocess, 10.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /run/media/baecker/data/programs/Fiji/mri-tools/piroplasma/src/runs/detect/val-7
