# %%
import os.path

project_file = "bbs.yaml"
assert os.path.exists(project_file)

# %%
from ultralytics import YOLO
# Load a custom trained YOLO26n model
model = YOLO('runs/detect/train-11/weights/best.pt')

# %%
metrics = model.val()
# Out:
# Ultralytics 8.4.75 🚀 Python-3.10.19 torch-2.12.1+cu130 CUDA:0 (Quadro RTX 5000, 15920MiB)
# YOLO26n summary (fused): 122 layers, 2,375,421 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3180.9±1668.7 MB/s, size: 7500.3 KB)
# val: Scanning /media/baecker/data/programs/Fiji/mri-tools/piroplasma/src/datasets/work/val.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 3.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.7s2.8s
#                    all         38        574      0.725      0.673      0.753       0.59
#                healthy         38        487      0.867       0.85      0.923      0.749
#               infected         38         66      0.812      0.455      0.716      0.608
#                 popped         13         21      0.496      0.714      0.621      0.413
# ...
