# %%
import os.path

project_file = "bbs.yaml"
assert os.path.exists(project_file)

# %%
from ultralytics import YOLO
# Load a custom trained YOLO26n model
model = YOLO('runs/detect/train-12/weights/best.pt')

# %%
metrics = model.val()
# Out:
# Ultralytics 8.4.75 🚀 Python-3.10.19 torch-2.12.1+cu130 CUDA:0 (Quadro RTX 5000, 15920MiB)
# YOLO26n summary (fused): 122 layers, 2,375,421 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3624.1±1543.7 MB/s, size: 7500.3 KB)
# val: Scanning /media/baecker/data/programs/Fiji/mri-tools/piroplasma/src/datasets/work/val.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 2.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.3s/it 3.8s2.9s
#                    all         38        574      0.812      0.705       0.77      0.616
#                healthy         38        487      0.899      0.924      0.945      0.781
#               infected         38         66      0.873      0.523      0.691      0.607
#                 popped         13         21      0.663      0.667      0.675       0.46
# Speed: 10.5ms preprocess, 18.8ms inference, 0.0ms loss, 5.3ms postprocess per image
# Results saved to /media/baecker/data/programs/Fiji/mri-tools/piroplasma/src/runs/detect/val-5
